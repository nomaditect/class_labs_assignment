# %% [markdown]
# # Dali's Holiday

# %% [markdown]
# #### The purpose of ther this notebook is to describe a holday desination for a man with a moustache.

# %%
name = input("Please provide your name? ")
print("hola Dali")
# Out:
# Please provide your name? nerd
# hola Dali

# %%
#Dalis portrait

# %% [markdown]
# ![philippe-halsman-salvador-dali,-dalis-mustache.jpeg](attachment:philippe-halsman-salvador-dali,-dalis-mustache.jpeg)

# %%
holiday_destination = input("where is your favoirite holiday destination? ")
print("enjoy your stay at", holiday_destination)
# Out:
# where is your favoirite holiday destination?home
# enjoy your stay in home

# %% [markdown]
# ### While on holiday the things I love to do are...
#
# - <font color='green'>  Sunbath </font>
# - **Eat** fish + **Drink** wine
# - _Smoke_ my *Pipe*

# %% [markdown]
# ![Screenshot%202021-10-18%20at%2017.20.18.png](attachment:Screenshot%202021-10-18%20at%2017.20.18.png)

# %% [markdown]
# ## <font color='green'>  See my holiday house here 👇 </font>

# %% [markdown]
# ## [Dali's seaside home](https://www.youtube.com/watch?v=-7fnCm6tlEY)
