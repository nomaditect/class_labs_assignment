# %% [markdown]
# # Lab | Customer analysis round 1

# %% [markdown]
# ## Import numpy and panda libraries and select the directory

# %%
#import numpy and panda libraries
import numpy as np 
import pandas as pd

# %%
# %ls
# Out:
#  El volumen de la unidad C es Windows
#  El n£mero de serie del volumen es: D82E-9E80
#
#  Directorio de C:\Users\glori\Documents\Jupyternotebook\ironhack\week1\lab_customeranalysis_round1master
#
# 19/10/2021  15:10    <DIR>          .
# 19/10/2021  15:10    <DIR>          ..
# 16/10/2020  12:35    <DIR>          .github
# 16/10/2020  12:35           145.932 file1.csv
# 16/10/2020  12:35            92.344 file2.csv
# 16/10/2020  12:35           625.674 file3.csv
# 16/10/2020  12:35    <DIR>          files_for_lab
# 16/10/2020  12:35             1.581 readme.md
#                4 archivos        865.531 bytes
#                4 dirs  97.245.589.504 bytes libres

# %%
#change the directory
# %cd C:\Users\glori\Documents\Jupyternotebook\ironhack\week1\lab_customeranalysis_round1master
# Out:
# C:\Users\glori\Documents\Jupyternotebook\ironhack\week1\lab_customeranalysis_round1master

# %% [markdown]
# ## Read the files

# %%
#read the files
file1=pd.read_csv('file1.csv')
file2=pd.read_csv('file2.csv')
file3=pd.read_csv('file3.csv')

# %%
file1.head() #it prints the head of the data set 1
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
file1.shape #Return a tuple representing the dimensionality of the DataFrame.
# Out:
# (4008, 11)

# %%
file2.head() #it prints the head of the data set 2
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
file2.shape #Return a tuple representing the dimensionality of the DataFrame.
# Out:
# (996, 11)

# %%
file3.head() #it prints the head of the data set 3
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Total Claim Amount  Vehicle Class
# ...

# %%
file3.shape #Return a tuple representing the dimensionality of the DataFrame.
# Out:
# (7070, 11)

# %% [markdown]
# ## Standarize the header names 1

# %%
#standarize the header names 1
file1 = file1.rename(columns={'Customer':'Customer','ST':'State','GENDER':'Gender','Education':'Education','Customer Lifetime Value':'Customer Lifetime Value','Income':'Income','Monthly Premium Auto':'Monthly Premium Auto','Number of Open Complaints':'Number of Open Complaints','Total Claim Amount':'Total Claim Amount','Policy Type':'Policy Type','Vehicle Class':'Vehicle Class'})
file2 = file2.rename(columns={'Customer':'Customer','ST':'State','GENDER':'Gender','Education':'Education','Customer Lifetime Value':'Customer Lifetime Value','Income':'Income','Monthly Premium Auto':'Monthly Premium Auto','Number of Open Complaints':'Number of Open Complaints','Total Claim Amount':'Total Claim Amount','Policy Type':'Policy Type','Vehicle Class':'Vehicle Class'})
file3 = file3.rename(columns={'Customer':'Customer','State':'State','Gender':'Gender','Education':'Education','Customer Lifetime Value':'Customer Lifetime Value','Income':'Income','Monthly Premium Auto':'Monthly Premium Auto','Number of Open Complaints':'Number of Open Complaints','Total Claim Amount':'Total Claim Amount','Policy Type':'Policy Type','Vehicle Class':'Vehicle Class'})

# %%
file1.head() #it prints the head of the data set 1
# Out:
#   Customer       State Gender             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
file2.head() #it prints the head of the data set 2
# Out:
#   Customer       State Gender Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
file3.head() #it prints the head of the data set 3
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Total Claim Amount  Vehicle Class
# ...

# %% [markdown]
# ## Rearrange the columns and concatenate the data tables

# %%
#Rearrange the columns in the dataframe as needed
file1 = file1[["Customer", "State", "Gender","Education","Customer Lifetime Value","Income","Monthly Premium Auto","Number of Open Complaints","Policy Type","Vehicle Class","Total Claim Amount"]]
file2 = file2[["Customer", "State", "Gender","Education","Customer Lifetime Value","Income","Monthly Premium Auto","Number of Open Complaints","Policy Type","Vehicle Class","Total Claim Amount"]]
file3 = file3[["Customer", "State", "Gender","Education","Customer Lifetime Value","Income","Monthly Premium Auto","Number of Open Complaints","Policy Type","Vehicle Class","Total Claim Amount"]]

# %%
#Concatenate the three dataframes
datanew=pd.concat([file1,file2,file3],axis=0)

# %%
#standarize the header names 2
columns=datanew.columns
cols=[]
for i in range(len(datanew.columns)):
    cols.append(datanew.columns[i].upper())
#this is the function data.columns.upper()

# %%
datanew.columns=cols

# %%
datanew.reset_index(drop=True, inplace=True)  #inplace merge, not create a new one

# %%
datanew
# Out:
#       CUSTOMER       STATE GENDER             EDUCATION  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  California      M              Bachelor
# 12070  PK87824  California      F               College
# 12071  TD14365  California      M              Bachelor
# 12072  UP19263  California      M               College
# 12073  Y167826  California      M               College
#
#       CUSTOMER LIFETIME VALUE   INCOME  MONTHLY PREMIUM AUTO  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# 2                 1288743.17%  48767.0                 108.0
# ...

# %%
datanew.shape
# Out:
# (12074, 11)

# %% [markdown]
# ## Columns Data Type

# %%
#which columns are numerical? which categorical?
datanew.dtypes
# Out:
# CUSTOMER                      object
# STATE                         object
# GENDER                        object
# EDUCATION                     object
# CUSTOMER LIFETIME VALUE       object
# INCOME                       float64
# MONTHLY PREMIUM AUTO         float64
# NUMBER OF OPEN COMPLAINTS     object
# POLICY TYPE                   object
# VEHICLE CLASS                 object
# TOTAL CLAIM AMOUNT           float64
# dtype: object

# %% [markdown]
# ## Data Cleaning operations

# %%
# Delete the column education and the number of open complaints from the dataset
datacl=datanew.drop(['EDUCATION','NUMBER OF OPEN COMPLAINTS'],axis=1) #this is not delete, we can always restore

# %%
datacl.reset_index(drop=True, inplace=True)  #inplace merge, not create a new one

# %%
datacl
# Out:
#       CUSTOMER       STATE GENDER CUSTOMER LIFETIME VALUE   INCOME  \
# 0      RB50392  Washington    NaN                     NaN      0.0
# 1      QZ44356     Arizona      F              697953.59%      0.0
# 2      AI49188      Nevada      F             1288743.17%  48767.0
# 3      WW63253  California      M              764586.18%      0.0
# 4      GA49547  Washington      M              536307.65%  36357.0
# ...        ...         ...    ...                     ...      ...
# 12069  LA72316  California      M             23405.98798  71941.0
# 12070  PK87824  California      F             3096.511217  21604.0
# 12071  TD14365  California      M             8163.890428      0.0
# 12072  UP19263  California      M             7524.442436  21941.0
# 12073  Y167826  California      M             2611.836866      0.0
#
#        MONTHLY PREMIUM AUTO     POLICY TYPE  VEHICLE CLASS  TOTAL CLAIM AMOUNT
# 0                    1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
#Correct the values in the column customer lifetime value. They are given as a percent, 
#so multiply them by 100 and change dtype to numerical type.
datacl['CUSTOMER LIFETIME VALUE']*=100
datacl['CUSTOMER LIFETIME VALUE']=pd.to_numeric(datacl['CUSTOMER LIFETIME VALUE'],errors='coerce')

# %%
datacl
# Out:
#       CUSTOMER       STATE GENDER  CUSTOMER LIFETIME VALUE   INCOME  \
# 0      RB50392  Washington    NaN                      NaN      0.0
# 1      QZ44356     Arizona      F                      NaN      0.0
# 2      AI49188      Nevada      F                      NaN  48767.0
# 3      WW63253  California      M                      NaN      0.0
# 4      GA49547  Washington      M                      NaN  36357.0
# ...        ...         ...    ...                      ...      ...
# 12069  LA72316  California      M             2.340599e+06  71941.0
# 12070  PK87824  California      F             3.096511e+05  21604.0
# 12071  TD14365  California      M             8.163890e+05      0.0
# 12072  UP19263  California      M             7.524442e+05  21941.0
# 12073  Y167826  California      M             2.611837e+05      0.0
#
#        MONTHLY PREMIUM AUTO     POLICY TYPE  VEHICLE CLASS  TOTAL CLAIM AMOUNT
# ...

# %%
datacl.dtypes
# Out:
# CUSTOMER                    object
# STATE                       object
# GENDER                      object
# CUSTOMER LIFETIME VALUE    float64
# INCOME                     float64
# MONTHLY PREMIUM AUTO       float64
# POLICY TYPE                 object
# VEHICLE CLASS               object
# TOTAL CLAIM AMOUNT         float64
# dtype: object

# %%
#Check for duplicate rows in the data and remove if any.
datacl=data.drop_duplicates()

# %%
datacl.shape
# Out:
# (9135, 11)

# %%
#Filter out the data for customers who have an income of 0 or less.
filteredincome=datacl[(datacl["INCOME"]<=0)]

# %%
filteredincome.shape
# Out:
# (2294, 11)
